# %%
from skimage.io import imread
from skimage.transform import resize
from sklearn.ensemble import RandomForestClassifier as RF
import glob
import os
from sklearn import cross_validation
from sklearn.cross_validation import StratifiedKFold as KFold
from sklearn.metrics import classification_report
from matplotlib import pyplot as plt
from matplotlib import colors
from pylab import cm
import numpy as np
import pandas as pd

from sklearn import decomposition
from sklearn.decomposition import RandomizedPCA
from sklearn import svm
from sklearn import metrics
from sklearn.pipeline import Pipeline
from sklearn.cross_validation import train_test_split
from sklearn.svm import LinearSVC
from time import time
#from multiprocessing import Pool
#pool = Pool(processes = 6)

from sklearn.linear_model import SGDClassifier
from sklearn.grid_search import GridSearchCV
from sklearn.grid_search import GridSearchCV, RandomizedSearchCV
from operator import itemgetter
from scipy.stats import randint as sp_randint
from sklearn.feature_extraction import image

# %%
import numpy as np
from scipy import linalg
from sklearn.utils import array2d, as_float_array
from sklearn.base import TransformerMixin, BaseEstimator
 
 
class ZCA(BaseEstimator, TransformerMixin):
 
    def __init__(self, regularization=10**-5, copy=False):
        self.regularization = regularization
        self.copy = copy
 
    def fit(self, X, y=None):
        X = array2d(X)
        X = as_float_array(X, copy = self.copy)
        self.mean_ = np.mean(X, axis=0)
        X -= self.mean_
        sigma = np.dot(X.T,X) / X.shape[1]
        U, S, V = linalg.svd(sigma)
        tmp = np.dot(U, np.diag(1/np.sqrt(S+self.regularization)))
        self.components_ = np.dot(tmp, U.T)
        return self
 
    def transform(self, X):
        X = array2d(X)
        X_transformed = X - self.mean_
        X_transformed = np.dot(X_transformed, self.components_.T)
        return X_transformed

# %%
# Scoring function for kaggle competition
def multiclass_log_loss(y_true, y_pred, eps=1e-15):
    predictions = np.clip(y_pred, eps, 1 - eps)

    # normalize row sums to 1
    predictions /= predictions.sum(axis=1)[:, np.newaxis]

    actual = np.zeros(y_pred.shape)
    n_samples = actual.shape[0]
    actual[np.arange(n_samples), y_true.astype(int)] = 1
    vectsum = np.sum(actual * np.log(predictions))
    loss = -1.0 / n_samples * vectsum
    return loss

# Utility function to report best scores
def report(grid_scores, n_top=3):
    top_scores = sorted(grid_scores, key=itemgetter(1), reverse=True)[:n_top]
    for i, score in enumerate(top_scores):
        print("Model with rank: {0}".format(i + 1))
        print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
              score.mean_validation_score,
              np.std(score.cv_validation_scores)))
        print("Parameters: {0}".format(score.parameters))
        print("")
        
 
def print_scoring(y_pred):
    y_class = np.array([list(x).index(max(x)) for x in y_pred])
    print "classifier final score:    ", multiclass_log_loss(y_test, y_pred)
    print "f1-score: %.3f   accuracy: %.3f   precision: %.3f   recall: %.3f" % (metrics.f1_score(y_test, y_class), 
        metrics.accuracy_score(y_test, y_class), metrics.precision_score(y_test, y_class), metrics.recall_score(y_test, y_class))
    print metrics.classification_report(y_test, y_class)

def plot_cv_results_orig(grid_search):
    #print grid_search.grid_scores_[0][0].keys()
    types = [x for x in grid_search.grid_scores_[0][0].keys() if isinstance( grid_search.grid_scores_[0][0][x], ( int, float, long, complex ) ) ]
    #print types
    num_figures = len(types)
    fig = plt.figure(figsize=(16,4))
    for i in range(num_figures):
        param = types[i]
        ax = fig.add_subplot(1,num_figures, i+1, xticks=[], yticks=[])
        vals = np.array([[x[0][param], x[1]] for x in grid_search.grid_scores_])
        vals = vals.T
        ax.scatter(vals[0,:], vals[1,:])
        plt.xlabel(param)
        plt.ylabel('score')
        
def plot_cv_results(grid_search):
    num_figures = len(grid_search.grid_scores_[0][0].keys())

    fig = plt.figure(figsize=(16,4))
    for i in range(num_figures):
        param = grid_search.grid_scores_[0][0].keys()[i]

        ax = fig.add_subplot(1,num_figures, i+1, xticks=[], yticks=[])
        
        val = grid_search.grid_scores_[0][0][param]
        if isinstance(val, ( int, float, long, complex )):
            vals = np.array([[x[0][param], x[1]] for x in grid_search.grid_scores_])
        elif isinstance(val, ( bool )):
            vals = np.array([[int(x[0][param]), x[1]] for x in grid_search.grid_scores_])
        elif isinstance(val, ( str )):
            lst = list(set(([x[0][param] for x in grid_search.grid_scores_])))
            vals = np.array([[lst.index(x[0][param]), x[1]] for x in grid_search.grid_scores_])
        print vals
        vals = vals.T
        
        ax.scatter(vals[0,:], vals[1,:])
        plt.xlabel(param)
        plt.ylabel('score')
        
multiclass_log_loss_func = metrics.make_scorer(score_func = multiclass_log_loss, greater_is_better=False, needs_proba=True)

# %%
data_dir = '/home/tony/ML/plankton/data'

train_dir = os.path.join(data_dir, 'train')
train_dirs = list(set(glob.glob(os.path.join(train_dir, '*'))))
train_paths_by_type = {os.path.basename(path): list(set(glob.glob(os.path.join(path, '*')))) for path in train_dirs}

test_dir = os.path.join(data_dir, 'test')
test_paths = list(set(glob.glob(os.path.join(test_dir, '*'))))
test_files = [os.path.basename(p) for p in test_paths]

img_dims = (25,25)
img_width, img_height = img_dims
imageSize = img_height*img_width
num_train_rows = sum([len(n) for n in train_paths_by_type.values()]) #30336
num_test_rows = len(test_paths)

plankton_types = []
train_files = []
test_files = []

# %%
# %store -r X
# %store -r y
# %store -r X_submission
# %store -r X_submission_images
# %store -r X_images

# %%
def load_images():
    print "loading and resizing submission images"
    t0 = time()
    file_index = 0
    for f in test_paths:
        img = imread(f, as_grey=True)
        X_submission_images.append(img)
        img_resized = resize(img, img_dims)
        X_submission[file_index, 0:imageSize] = np.reshape(img_resized, (1, imageSize))
        file_index += 1
    
        report = [int((j+1)/20. * num_test_rows) for j in range(20)]
        if file_index in report: print np.ceil(file_index * 100.0 / num_test_rows), "% done"
    print "completed reading submission images in %.2f seconds" % (time()-t0)
    
    print "loading and resizing the training images"
    t0 = time()
    file_index, type_index = 0, 0
    for plankton_type in train_paths_by_type:
        files_for_type = train_paths_by_type[plankton_type]
        for f in files_for_type:
            img = imread(f, as_grey=True)
            X_images.append(img)
            img_resized = resize(img, img_dims)
            train_files.append(f)
            X[file_index, 0:imageSize] = np.reshape(img_resized, (1, imageSize))
            y[file_index] = type_index
            file_index += 1
    
            report = [int((j+1)/5. * num_train_rows) for j in range(5)]
            if file_index in report: print np.ceil(file_index * 100.0 / num_train_rows), "% done"
        type_index += 1
    print "completed reading training images in %.2f seconds" % (time()-t0)
    
    print "images loaded! X, y are the training images, and X_submission is the test images"


if 'X_images' in globals():
    print 'variables already loaded into memory! dont need to read image files.'
else:
    X = np.zeros((num_train_rows, imageSize), dtype=float)
    y = np.zeros(num_train_rows)
    X_submission = np.zeros((num_test_rows, imageSize), dtype=float)
    X_submission_images, X_images = [], []
    load_images()
    # %store X
    # %store y
    # %store X_submission
    # %store X_submission_images
    # %store X_images
# Out:
# variables already loaded into memory! dont need to read image files.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.40)

# %% [markdown]
# # Creating the patch k-means thing

# %%
from sklearn.feature_extraction.image import PatchExtractor
from sklearn.cluster import KMeans, MiniBatchKMeans

# %%
num_centers = 100
# %store -r k100means
if 'k100means' in globals():
    print 'k100means loaded from memory'
else:
    patchesExtractor = PatchExtractor(patch_size=(8,8), max_patches=80, random_state=0)
    patches = patchesExtractor.transform(X_train.reshape((X_train.shape[0],img_height,img_width)))
    patches = patches.reshape((patches.shape[0], 64))

    t0 = time()
    k100means = MiniBatchKMeans(n_clusters=num_centers, init_size=num_centers)
    k100means.fit(patches)
    del patches
    # %store k100means
    print "fit k-means to patches in %.2f seconds" % (time() - t0)
# Out:
# k100means loaded from memory

# %%
#fig = plt.figure(figsize=(12,12))
#for i in range(100):
#    ax = fig.add_subplot(10,10, i+1, xticks=[], yticks=[])
#    im = k100means.cluster_centers_[i].reshape((8,8))
#    ax.imshow(im, cmap=plt.cm.bone)

# %%
#################################################################
#                   Latest kmeans patches logic:                #
#################################################################

patch_dims = (8,8)
patch_size = 64
num_patches = image.extract_patches_2d(np.ones((25,25)), (8,8)).shape[0]

def getSubMatrices(M, x_num, y_num):
    y_width, x_width = M.shape[0]/y_num, M.shape[1]/x_num
    new_M = np.zeros_like(M).reshape(x_num*y_num, M.shape[0]*M.shape[1]/(x_num*y_num), M.shape[2])
    #print "new_M shape: ", new_M.shape
    for y in range(y_num):
        for x in range(x_num):
            #print "x=", x, "y=", y, "idx=", x+y*x_num
            #print M[y*y_width:(y+1)*y_width,x*x_width:(x+1)*x_width]
            new_M[x + y*x_num,:,:] = M[y*y_width:(y+1)*y_width,x*x_width:(x+1)*x_width,:].reshape(x_width*y_width,M.shape[2])
    return new_M

def transform_img_with_kmeans(orig_img):
    img = orig_img
    if len(img.shape) == 1:
        img = img.reshape(img_dims)
    img_patches = image.extract_patches_2d(img, patch_dims)
    img_patches_flat = img_patches.reshape((img_patches.shape[0], patch_size))
    centers = k100means.transform(img_patches_flat)
    centers = centers.reshape(sqrt(num_patches), sqrt(num_patches), num_centers)
    centers_segmented = getSubMatrices(centers, 2, 2)
    centers_avg = centers_segmented.mean(axis=1).reshape((4*num_centers))
    return centers_avg
    #centers_avg = centers.reshape((4, num_patches/4, num_centers)).mean(axis=2).reshape((X_train.shape[0],4*num_centers))

def transform_images_to_kmeans_domain(images):
    return np.array([transform_img_with_kmeans(img) for img in images])


if 'centers_train' in globals():
    print "centers_train loaded from memory"
else:
    print "time:", datetime.datetime.now()
    t0 = time()
    centers_train = transform_images_to_kmeans_domain(X_train)
    print "centers_train loaded!"
    centers_test = transform_images_to_kmeans_domain(X_test)
    print "centers test loaded!"
    print "completed in %.2f seconds" % (time() - t0)

# %% [markdown]
# # Doing classification now:

# %%
print "starting param sweep"
print "time:", datetime.datetime.now()
t0 = time()
pipe = Pipeline(steps=[('pca', RandomizedPCA()), ('svm', svm.SVC())])

param_dist = dict(pca__n_components=[25,50,100],
                  pca__whiten=[True, False],
                  pca__random_state=[0],
                  svm__C=[0.4, 1.0, 6.0],
                  svm__kernel=["linear", "rbf"])

#grid_search = RandomizedSearchCV(pipe, param_distributions=param_dist, n_jobs=8, n_iter=48)
grid_search = GridSearchCV(pipe, param_grid=param_dist, n_jobs=8, refit=False, verbose=1)

grid_search.fit(centers_train, y_train)
print "completed in %.2f seconds" % (time() - t0)

print "doing a fit"
pipe.set_params(**grid_search.best_params_)
pipe.fit(centers_train, y_train)
y_pred = pipe.predict_proba(centers_test)
print "finished fit"

print_scoring(y_pred)
report(grid_search.grid_scores_, 28)
# Out:
# starting param sweep
# time: 2015-01-30 00:21:25.392422
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# [Parallel(n_jobs=8)]: Done   1 jobs       | elapsed:   37.6s
# [Parallel(n_jobs=8)]: Done  50 jobs       | elapsed:  6.2min
# [Parallel(n_jobs=8)]: Done  94 out of 108 | elapsed: 11.8min remaining:  1.8min
# [Parallel(n_jobs=8)]: Done 108 out of 108 | elapsed: 13.9min finished
# completed in 836.95 seconds
# doing a fit
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-c25bfef74f5a> in <module>()
#      19 pipe.set_params(**grid_search.best_params_)
#      20 pipe.fit(centers_train, y_train)
# ---> 21 y_pred = pipe.predict_proba(centers_test)
#      22 print "finished fit"
#      23
#
# /home/tony/anaconda/lib/python2.7/site-packages/sklearn/pipeline.pyc in predict_proba(self, X)
#     157         for name, transform in self.steps[:-1]:
#     158             Xt = transform.transform(Xt)
# --> 159         return self.steps[-1][-1].predict_proba(Xt)
#     160
#     161     def decision_function(self, X):
#
# /home/tony/anaconda/lib/python2.7/site-packages/sklearn/svm/base.pyc in predict_proba(self)
#     505         datasets.
#     506         """
# --> 507         self._check_proba()
#     508         return self._predict_proba
#     509
#
# /home/tony/anaconda/lib/python2.7/site-packages/sklearn/svm/base.pyc in _check_proba(self)
#     475         if not self.probability:
#     476             raise AttributeError("predict_proba is not available when"
# --> 477                                  " probability=%r" % self.probability)
#     478         if self._impl not in ('c_svc', 'nu_svc'):
#     479             raise AttributeError("predict_proba only implemented for SVC"
#
# AttributeError: predict_proba is not available when probability=False

# %%
print "doing a fit"
pipe.set_params(**grid_search.best_params_)
pipe.set_params(svm__probability= True)
pipe.fit(centers_train, y_train)
y_pred = pipe.predict_proba(centers_test)
print "finished fit"

print_scoring(y_pred)
report(grid_search.grid_scores_, 28)
# Out:
# doing a fit
# finished fit
# classifier final score:
#  1.64209518958
# f1-score: 0.571   accuracy: 0.585   precision: 0.577   recall: 0.585
#              precision    recall  f1-score   support
#
#         0.0       0.82      0.76      0.79       157
#         1.0       0.71      0.16      0.26        76
#         2.0       0.67      0.25      0.36        16
#         3.0       0.50      0.38      0.43        37
#         4.0       0.52      0.46      0.49       139
#         5.0       0.38      0.45      0.41        76
#         6.0       0.25      0.19      0.22        26
#         7.0       0.53      0.33      0.41        49
#         8.0       0.50      0.48      0.49       218
#         9.0       0.31      0.29      0.30       140
#        10.0       0.69      0.66      0.67       323
#        11.0       0.51      0.49      0.50       191
#        12.0       0.40      0.07      0.12        28
#        13.0       0.50      0.21      0.29        24
#        14.0       0.00      0.00      0.00         9
#        15.0       0.40      0.11      0.17        19
#        16.0       0.53      0.32      0.40        25
#        17.0       0.53      0.45      0.49       207
#        18.0       0.00      0.00      0.00         7
#        19.0       0.50      0.06      0.11        17
#        20.0       0.55      0.40      0.47       254
#        21.0       0.60      0.43      0.50         7
#        22.0       0.00      0.00      0.00        12
#        23.0       0.00      0.00      0.00        18
#        24.0       0.46      0.67      0.55         9
#        25.0       0.64      0.55      0.59        29
#        26.0       0.00      0.00      0.00        11
#        27.0       0.40      0.43      0.41        42
#        28.0       0.67      0.45      0.54        62
#        29.0       0.85      0.55      0.67        40
#        30.0       0.43      0.47      0.45        55
#        31.0       0.72      0.66      0.69        32
#        32.0       0.57      0.57      0.57        51
#        33.0       0.00      0.00      0.00         3
#        34.0       0.38      0.35      0.37       198
#        35.0       0.30      0.04      0.07        71
#        36.0       0.40      0.25      0.31         8
#        37.0       0.50      0.42      0.46        19
#        38.0       0.82      0.84      0.83       368
#        39.0       0.32      0.21      0.26        47
#        40.0       0.50      0.06      0.11        16
#        41.0       0.30      0.10      0.15        31
#        42.0       0.50      0.65      0.56       457
#        43.0       0.34      0.47      0.40       361
#        44.0       0.68      0.66      0.67        35
#        45.0       0.34      0.26      0.29       108
#        46.0       0.37      0.22      0.27       134
#        47.0       0.00      0.00      0.00         5
#        48.0       0.33      0.08      0.13        12
#        49.0       0.00      0.00      0.00         6
#        50.0       0.66      0.71      0.69        97
#        51.0       0.59      0.27      0.37        48
#        52.0       0.00      0.00      0.00        14
#        53.0       0.62      0.31      0.42        16
#        54.0       0.80      0.87      0.83       385
#        55.0       0.35      0.37      0.36        59
#        56.0       0.76      0.81      0.78       172
#        57.0       0.23      0.25      0.24        24
#        58.0       0.61      0.81      0.70       276
#        59.0       0.25      0.13      0.17        15
#        60.0       0.00      0.00      0.00         5
#        61.0       0.51      0.51      0.51       106
#        62.0       0.61      0.70      0.65        43
#        63.0       0.00      0.00      0.00        21
#        64.0       0.32      0.26      0.29        93
#        65.0       0.43      0.58      0.49        62
#        66.0       0.22      0.49      0.31        88
#        67.0       0.52      0.61      0.56       271
#        68.0       0.00      0.00      0.00         5
#        69.0       0.34      0.35      0.35        77
#        70.0       0.24      0.22      0.23        27
#        71.0       0.00      0.00      0.00         6
#        72.0       0.79      0.80      0.80        86
#        73.0       0.35      0.22      0.27        92
#        74.0       0.62      0.15      0.24        53
#        75.0       0.00      0.00      0.00        18
#        76.0       0.00      0.00      0.00        16
#        77.0       0.00      0.00      0.00         5
#        78.0       0.00      0.00      0.00         3
#        79.0       0.75      0.81      0.78       152
#        80.0       0.75      0.25      0.38        12
#        81.0       0.84      0.65      0.74        49
#        82.0       0.76      0.88      0.82       191
#        83.0       0.67      0.68      0.67       286
#        84.0       0.55      0.60      0.58        35
#        85.0       0.88      0.59      0.71        37
#        86.0       0.06      0.07      0.06       172
#        87.0       0.98      0.91      0.95        70
#        88.0       0.22      0.16      0.19       146
#        89.0       0.90      0.91      0.90       821
#        90.0       0.52      0.73      0.61       259
#        91.0       0.52      0.33      0.40       123
#        92.0       0.51      0.47      0.49        97
#        93.0       0.00      0.00      0.00         6
#        94.0       0.00      0.00      0.00         7
#        95.0       0.27      0.26      0.26        46
#        96.0       0.25      0.09      0.13        34
#        97.0       0.17      0.20      0.19        45
#        98.0       0.59      0.64      0.61       276
#        99.0       0.70      0.59      0.64        32
#       100.0       0.54      0.27      0.36        26
#       101.0       0.74      0.65      0.69        26
#       102.0       0.54      0.49      0.51        53
#       103.0       0.00      0.00      0.00        22
#       104.0       0.77      0.71      0.74       143
#       105.0       0.85      0.86      0.85       479
#       106.0       0.67      0.55      0.60        53
#       107.0       0.44      0.31      0.36        26
#       108.0       0.35      0.47      0.40        36
#       109.0       0.58      0.73      0.64       792
#       110.0       0.00      0.00      0.00        16
#       111.0       0.50      0.11      0.17        19
#       112.0       0.82      0.89      0.85       198
#       113.0       0.50      0.25      0.33        12
#       114.0       0.52      0.52      0.52       204
#       115.0       0.40      0.41      0.41        51
#       116.0       0.53      0.94      0.68       132
#       117.0       0.00      0.00      0.00         2
#       118.0       0.25      0.31      0.28       152
#       119.0       0.36      0.23      0.28        53
#       120.0       0.69      0.58      0.63       276
#
# avg / total       0.58      0.59      0.57     12135
#
# Model with rank: 1
# Mean validation score: 0.549 (std: 0.002)
# Parameters: {'pca__n_components': 100, 'svm__C': 6.0, 'pca__random_state': 0, 'svm__kernel': 'rbf', 'pca__whiten': True}
#
# Model with rank: 2
# Mean validation score: 0.532 (std: 0.002)
# Parameters: {'pca__n_components': 50, 'svm__C': 6.0, 'pca__random_state': 0, 'svm__kernel': 'rbf', 'pca__whiten': True}
#
# Model with rank: 3
# Mean validation score: 0.521 (std: 0.002)
# Parameters: {'pca__n_components': 100, 'svm__C': 1.0, 'pca__random_state': 0, 'svm__kernel': 'rbf', 'pca__whiten': True}
#
# Model with rank: 4
# Mean validation score: 0.509 (std: 0.001)
# Parameters: {'pca__n_components': 25, 'svm__C': 6.0, 'pca__random_state': 0, 'svm__kernel': 'rbf', 'pca__whiten': True}
#
# Model with rank: 5
# Mean validation score: 0.504 (std: 0.002)
# Parameters: {'pca__n_components': 50, 'svm__C': 1.0, 'pca__random_state': 0, 'svm__kernel': 'rbf', 'pca__whiten': True}
#
# Model with rank: 6
# Mean validation score: 0.488 (std: 0.002)
# Parameters: {'pca__n_components': 100, 'svm__C': 0.4, 'pca__random_state': 0, 'svm__kernel': 'linear', 'pca__whiten': True}
#
# Model with rank: 7
# Mean validation score: 0.482 (std: 0.005)
# Parameters: {'pca__n_components': 100, 'svm__C': 1.0, 'pca__random_state': 0, 'svm__kernel': 'linear', 'pca__whiten': True}
#
# Model with rank: 8
# Mean validation score: 0.476 (std: 0.007)
# Parameters: {'pca__n_components': 100, 'svm__C': 6.0, 'pca__random_state': 0, 'svm__kernel': 'linear', 'pca__whiten': True}
#
# Model with rank: 9
# Mean validation score: 0.475 (std: 0.003)
# Parameters: {'pca__n_components': 25, 'svm__C': 1.0, 'pca__random_state': 0, 'svm__kernel': 'rbf', 'pca__whiten': True}
#
# Model with rank: 10
# Mean validation score: 0.474 (std: 0.004)
# Parameters: {'pca__n_components': 50, 'svm__C': 0.4, 'pca__random_state': 0, 'svm__kernel': 'linear', 'pca__whiten': True}
#
# Model with rank: 11
# Mean validation score: 0.471 (std: 0.007)
# Parameters: {'pca__n_components': 50, 'svm__C': 1.0, 'pca__random_state': 0, 'svm__kernel': 'linear', 'pca__whiten': True}
#
# Model with rank: 12
# Mean validation score: 0.467 (std: 0.005)
# Parameters: {'pca__n_components': 50, 'svm__C': 6.0, 'pca__random_state': 0, 'svm__kernel': 'linear', 'pca__whiten': True}
#
# Model with rank: 13
# Mean validation score: 0.459 (std: 0.002)
# Parameters: {'pca__n_components': 100, 'svm__C': 6.0, 'pca__random_state': 0, 'svm__kernel': 'linear', 'pca__whiten': False}
#
# Model with rank: 14
# Mean validation score: 0.455 (std: 0.005)
# Parameters: {'pca__n_components': 100, 'svm__C': 0.4, 'pca__random_state': 0, 'svm__kernel': 'rbf', 'pca__whiten': True}
#
# Model with rank: 15
# Mean validation score: 0.454 (std: 0.001)
# Parameters: {'pca__n_components': 50, 'svm__C': 6.0, 'pca__random_state': 0, 'svm__kernel': 'linear', 'pca__whiten': False}
#
# Model with rank: 16
# Mean validation score: 0.449 (std: 0.004)
# Parameters: {'pca__n_components': 50, 'svm__C': 0.4, 'pca__random_state': 0, 'svm__kernel': 'rbf', 'pca__whiten': True}
#
# Model with rank: 17
# Mean validation score: 0.447 (std: 0.007)
# Parameters: {'pca__n_components': 25, 'svm__C': 1.0, 'pca__random_state': 0, 'svm__kernel': 'linear', 'pca__whiten': True}
#
# Model with rank: 18
# Mean validation score: 0.446 (std: 0.005)
# Parameters: {'pca__n_components': 25, 'svm__C': 6.0, 'pca__random_state': 0, 'svm__kernel': 'linear', 'pca__whiten': True}
#
# Model with rank: 19
# Mean validation score: 0.443 (std: 0.008)
# Parameters: {'pca__n_components': 25, 'svm__C': 0.4, 'pca__random_state': 0, 'svm__kernel': 'linear', 'pca__whiten': True}
#
# Model with rank: 20
# Mean validation score: 0.440 (std: 0.004)
# Parameters: {'pca__n_components': 25, 'svm__C': 6.0, 'pca__random_state': 0, 'svm__kernel': 'linear', 'pca__whiten': False}
#
# Model with rank: 21
# Mean validation score: 0.433 (std: 0.004)
# Parameters: {'pca__n_components': 25, 'svm__C': 0.4, 'pca__random_state': 0, 'svm__kernel': 'rbf', 'pca__whiten': True}
#
# Model with rank: 22
# Mean validation score: 0.432 (std: 0.001)
# Parameters: {'pca__n_components': 100, 'svm__C': 1.0, 'pca__random_state': 0, 'svm__kernel': 'linear', 'pca__whiten': False}
#
# Model with rank: 23
# Mean validation score: 0.429 (std: 0.002)
# Parameters: {'pca__n_components': 50, 'svm__C': 1.0, 'pca__random_state': 0, 'svm__kernel': 'linear', 'pca__whiten': False}
#
# Model with rank: 24
# Mean validation score: 0.423 (std: 0.003)
# Parameters: {'pca__n_components': 25, 'svm__C': 1.0, 'pca__random_state': 0, 'svm__kernel': 'linear', 'pca__whiten': False}
#
# Model with rank: 25
# Mean validation score: 0.418 (std: 0.005)
# Parameters: {'pca__n_components': 50, 'svm__C': 6.0, 'pca__random_state': 0, 'svm__kernel': 'rbf', 'pca__whiten': False}
#
# Model with rank: 26
# Mean validation score: 0.415 (std: 0.005)
# Parameters: {'pca__n_components': 100, 'svm__C': 0.4, 'pca__random_state': 0, 'svm__kernel': 'linear', 'pca__whiten': False}
#
# Model with rank: 27
# Mean validation score: 0.413 (std: 0.005)
# Parameters: {'pca__n_components': 50, 'svm__C': 0.4, 'pca__random_state': 0, 'svm__kernel': 'linear', 'pca__whiten': False}
#
# Model with rank: 28
# Mean validation score: 0.410 (std: 0.006)
# Parameters: {'pca__n_components': 25, 'svm__C': 6.0, 'pca__random_state': 0, 'svm__kernel': 'rbf', 'pca__whiten': False}
# /home/tony/anaconda/lib/python2.7/site-packages/sklearn/metrics/metrics.py:1771: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/tony/anaconda/lib/python2.7/site-packages/sklearn/metrics/metrics.py:1771: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/tony/anaconda/lib/python2.7/site-packages/sklearn/metrics/metrics.py:1771: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# # Creating the submission file

# %%
centers_submission = transform_images_to_kmeans_domain(X_submission)

print "starting training"
print "time:", datetime.datetime.now()
t0 = time()
pipe = Pipeline(steps=[('pca', RandomizedPCA(n_components = 100, whiten=True)), ('svm', svm.SVC(C=6.0, kernel='rbf', probability=True))])

pipe.fit(centers_train, y_train)
print "completed in %.2f seconds" % (time() - t0)


print "doing the prediction"
t0 = time()
y_submission = pipe.predict_proba(centers_submission)
print "finished predict in %.2f seconds" % (time() - t0)

# %% [markdown]
# # Generating the submission

# %%
submission_filenames = np.array([os.path.basename(x) for x in test_paths])
df = pd.DataFrame(y_submission, columns=train_paths_by_type.keys(), index=submission_filenames)
df.index.name = 'image'
header = sort(train_paths_by_type.keys())
df = df[header]
df.to_csv('fifth_submission.csv')

# %%
# !gzip fifth_submission.csv
# !ls *.gz

# %%
# Out:
# first_submission (copy).csv.gz	fourth_submission.csv.gz  third_submission.csv.gz
# first_submission.csv.gz		second_submission.csv.gz

# %%
# %pwd
# Out:
# u'/home/tony/code/python/notebooks/plankton'
